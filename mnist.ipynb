# %% [markdown]
# <a href="https://colab.research.google.com/github/icemintkaren/helloworld/blob/master/mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
# !git clone https://github.com/icemintkaren/helloworld.git
# Out:
# Cloning into 'helloworld'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6 (delta 0), reused 6 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), done.

# %%
# !python /content/helloworld/helloeworld.py
# Out:
# hello,world!

# %%
import torchvision
import torch
from torchvision import datasets, transforms
data_train = datasets.MNIST(root = "./data/train/",transform=transforms,train = True,download = True)
data_test = datasets.MNIST(root="./data/test/",transform = transforms,train = False)
# Out:
# ...
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./data/train/MNIST/raw/train-images-idx3-ubyte.gz to ./data/train/MNIST/raw
#
# ...
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./data/train/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/train/MNIST/raw
#
# ...
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./data/train/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/train/MNIST/raw
#
# ...
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./data/train/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/train/MNIST/raw
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-26-8c6ad7335cb9> in <module>()
#       3 from torchvision import datasets, transforms
#       4 data_train = datasets.MNIST(root = "./data/train/",transform=transforms,train = True,download = True)
# ...

# %%
tests
# Out:
# fatal: not a git repository (or any of the parent directories): .git
